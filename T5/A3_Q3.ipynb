# %%
# !pip install wandb

# %%
from datasets import load_dataset
from transformers import AutoTokenizer
from transformers import DataCollatorForSeq2Seq
import evaluate
import numpy as np
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
import wandb
import pickle
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home2/bagler/DL_Assignment_3/A3_Q3.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B192.168.3.79/home2/bagler/DL_Assignment_3/A3_Q3.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from datasets import load_dataset
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.3.79/home2/bagler/DL_Assignment_3/A3_Q3.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from transformers import AutoTokenizer
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.3.79/home2/bagler/DL_Assignment_3/A3_Q3.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from transformers import DataCollatorForSeq2Seq
#
# File ~/anaconda3/lib/python3.9/site-packages/datasets/__init__.py:34, in <module>
#      28 if _version.parse(pyarrow.__version__).major < 1:
#      29     raise ImportWarning(
# ...

# %%
wandb.init(project='DL_A3_Q3_GPU', entity='shubham22124')
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb version 0.14.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/home2/bagler/DL_Assignment_3/wandb/run-20230405_234459-r2oxm2br</code>
# Syncing run <strong><a href='https://wandb.ai/shubham22124/DL_A3_Q3_GPU/runs/r2oxm2br' target="_blank">emissary-frontier-2</a></strong> to <a href='https://wandb.ai/shubham22124/DL_A3_Q3_GPU' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/shubham22124/DL_A3_Q3_GPU' target="_blank">https://wandb.ai/shubham22124/DL_A3_Q3_GPU</a>
#  View run at <a href='https://wandb.ai/shubham22124/DL_A3_Q3_GPU/runs/r2oxm2br' target="_blank">https://wandb.ai/shubham22124/DL_A3_Q3_GPU/runs/r2oxm2br</a>
# ...

# %%
rouge = evaluate.load("rouge")

# %%
bleu = evaluate.load('bleu')

# %%
def preprocess_function(examples):
    inputs = [prefix + example[source_lang] for example in examples["translation"]]
    targets = [example[target_lang] for example in examples["translation"]]
    model_inputs = tokenizer(inputs, text_target=targets, max_length=128, truncation=True)
    return model_inputs

# %%
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels

# %%
def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)
    result = {}
    result_rouge = rouge.compute(predictions=decoded_preds, references=decoded_labels, rouge_types=['rougeL'])
    result["rogueL"] = result_rouge["rougeL"]
    result_bleu1 = bleu.compute(predictions=decoded_preds, references=decoded_labels, max_order=1)
    result["Bleu1"] = result_bleu1["bleu"]
    result_bleu2 = bleu.compute(predictions=decoded_preds, references=decoded_labels, max_order=2)
    result["Bleu2"] = result_bleu2["bleu"]
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
dataset = load_dataset('wmt16', 'de-en', split='train[:10%]')
dataset = dataset.train_test_split(test_size=0.2)
checkpoint = "t5-small"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
source_lang = "en"
target_lang = "de"
prefix = "translate English to German: "
# Out:
# Found cached dataset wmt16 (/home2/bagler/.cache/huggingface/datasets/wmt16/de-en/1.0.0/746749a11d25c02058042da7502d973ff410e73457f3d305fc1177dc0e8c4227)
# /home2/bagler/anaconda3/lib/python3.9/site-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
# tokenized_data = dataset.map(preprocess_function, batched=True)
# with open('tokenize.pkl', 'wb') as f:
#     pickle.dump(tokenized_data, f)

# %%
with open('tokenize.pkl', 'rb') as f:
    tokenized_data = pickle.load(f)

# %%
tokenized_data = tokenized_data.remove_columns(dataset["train"].column_names)
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="models",
    remove_unused_columns=False,
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=256,
    per_device_eval_batch_size=256,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=8,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=False,
    report_to="wandb"
)
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# Using cuda_amp half precision backend

# %%
trainer.train()
wandb.finish()
# Out:
# /home2/bagler/anaconda3/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 363910
#   Num Epochs = 8
#   Instantaneous batch size per device = 256
#   Total train batch size (w. parallel, distributed & accumulation) = 256
#   Gradient Accumulation steps = 1
#   Total optimization steps = 11376
#   Number of trainable parameters = 60506624
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
# ...

# %%
text = "translate English to German:For some reason, people have been avoiding me like the plague ever since I got back from India."
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("models/checkpoint-11000")
inputs = tokenizer(text, return_tensors="pt").input_ids
model = AutoModelForSeq2SeqLM.from_pretrained("models/checkpoint-11000")
outputs = model.generate(inputs, max_new_tokens=40, do_sample=True, top_k=30, top_p=0.95)
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded)
# Out:
# Wie oft hatte ich Sie gesagt, die Leute nicht überzubringen, ohne zunächst meine Erlaubnis zu beantragen.

# %%
dataset = load_dataset('wmt16', 'de-en', split='train[:10%]')
print(dataset)
# Out:
# ...
# Found cached dataset wmt16 (/home2/bagler/.cache/huggingface/datasets/wmt16/de-en/1.0.0/746749a11d25c02058042da7502d973ff410e73457f3d305fc1177dc0e8c4227)
# Dataset({
#     features: ['translation'],
#     num_rows: 454888
# })
